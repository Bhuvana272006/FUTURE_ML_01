# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvana272006/FUTURE_ML_01/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sales Forecasting using Random Forest Regression

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load Dataset
data=pd.read_csv("/content/stores_sales_forecasting.csv",encoding='latin1')

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 4      11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 2   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 3  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
# 4  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
# ...

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
#  Data Preprocessing

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['year'] = data['Order Date'].dt.year
data['month'] = data['Order Date'].dt.month
data['day'] = data['Order Date'].dt.day
data['day_of_week'] = data['Order Date'].dt.dayofweek
data['is_weekend'] = (data['day_of_week'] >= 5).astype(int)
data['quarter'] = data['Order Date'].dt.quarter

# %%
# Define input features (X) and target variable (y)
X = data[['Quantity','Discount','Profit',
          'year','month','day','day_of_week','is_weekend','quarter']]
y = data['Sales']

# %%
X.dtypes
# Out:
# Quantity         int64
# Discount       float64
# Profit         float64
# year             int32
# month            int32
# day              int32
# day_of_week      int32
# is_weekend       int64
# quarter          int32
# dtype: object

# %%
print(X)
# Out:
#       Quantity  Discount    Profit  year  month  day  day_of_week  is_weekend  \
# 0            2      0.00   41.9136  2016     11    8            1           0
# 1            3      0.00  219.5820  2016     11    8            1           0
# 2            5      0.45 -383.0310  2015     10   11            6           1
# 3            7      0.00   14.1694  2014      6    9            0           0
# 4            9      0.20   85.3092  2014      6    9            0           0
# ...        ...       ...       ...   ...    ...  ...          ...         ...
# 2116         4      0.32  -67.6704  2015      3   19            3           0
# 2117         1      0.00    6.4320  2016     12    5            0           0
# 2118         1      0.00   22.3548  2015      9    6            6           1
# 2119         3      0.20    4.1028  2014      1   21            1           0
# 2120         2      0.00   15.6332  2017      2   26            6           1
#
#       quarter
# 0           4
# ...

# %%
print(y)
# Out:
# 0        261.9600
# 1        731.9400
# 2        957.5775
# 3         48.8600
# 4       1706.1840
#           ...
# 2116     383.4656
# 2117      13.4000
# 2118      85.9800
# 2119      25.2480
# 2120      91.9600
# Name: Sales, Length: 2121, dtype: float64

# %%
# Split data into training (80%) and testing (20%)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=600,max_depth=15,  min_samples_split=6,min_samples_leaf=2, random_state=0)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=15, min_samples_leaf=2, min_samples_split=6,
#                       n_estimators=600, random_state=0)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# R2 Score: 0.6847922815083836

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))

plt.scatter(y_test[:200], y_pred[:200], alpha=0.7)

plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])



plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Random Forest - Actual vs Predicted")
plt.grid(True)
plt.show()

# %%
import pandas as pd

feature_importance = pd.Series(model.feature_importances_, index=X.columns)
feature_importance.sort_values().plot(kind='barh')
plt.title("Feature Importance")
plt.show()

# %% [markdown]
#  “The model achieved an R² score of ~0.68, indicating good predictive performance. Feature importance analysis shows that Quantity and Profit are key drivers of sales.”
